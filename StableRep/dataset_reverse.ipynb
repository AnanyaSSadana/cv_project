# %%
import torch
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import default_collate
from torchvision.utils import make_grid
from einops import rearrange
from PIL import Image
import pickle
from tqdm.notebook import tqdm
import os
from torchvision import transforms
import shutil

# %%
base_path = './SSL_embeddings/Real'
batch_size = 64
def reverse(class_names):
    for class_name in tqdm(class_names, desc="Processing Classes"):
        for i in range(1,6):
            file_path = f"{base_path}/{class_name}/{class_name}_image_embeddings_batch_{i}.pkl"
            with open(file_path, "rb") as f:
                items = pickle.load(f)
            for start_idx in tqdm(range(0, len(items), batch_size), desc="Batches", leave=False):
                batch = default_collate(items[start_idx:start_idx + batch_size])
                images = batch['image_array']
                for j, img in enumerate(images):
                    # print(img.shape)
                    img = img.permute(2,0,1)
                    # print(img.shape)
                    image = transforms.ToPILImage()(img)
                    image.save(f"{base_path}/{class_name}/{class_name}_{i}_{start_idx + j}.jpg", "JPEG")

# %%
reverse(["ADI", "BACK", "DEB", "LYM", "MUC", "MUS", "NORM", "STR", "TUM"])

# %%
def train_valid_spilit(class_names):
    for class_name in tqdm(class_names, desc="Processing Classes"):
        for i in range(1,6):
            # file_path = f"{base_path}/{class_name}/{class_name}_image_embeddings_batch_{i}.pkl"
            # with open(file_path, "rb") as f:
            #     items = pickle.load(f)
            for start_idx in range(0, 1000):
                if start_idx < 800:
                    img_move = f"{base_path}/{class_name}/{class_name}_{i}_{start_idx}.jpg"
                    if not os.path.exists(img_move):
                        print(f"Source file '{img_move}' does not exist.")
                        return
                    
                    # Check if the destination directory exists, if not, create it
                    destination_dir = os.path.dirname(f"{base_path}/train/{class_name}")
                    if not os.path.exists(destination_dir):
                        os.makedirs(destination_dir)
                    try:
                        shutil.move(img_move, destination_dir)
                        print(f"File '{img_move}' moved to '{destination_dir}' successfully.")
                    except Exception as e:
                        print(f"Error occurred while moving file: {e}")
                else:
                    img_move = f"{base_path}/{class_name}/{class_name}_{i}_{start_idx}.jpg"
                    if not os.path.exists(img_move):
                        print(f"Source file '{img_move}' does not exist.")
                        return
                    
                    # Check if the destination directory exists, if not, create it
                    destination_dir = os.path.dirname(f"{base_path}/val/{class_name}")
                    if not os.path.exists(destination_dir):
                        os.makedirs(destination_dir)
                    try:
                        shutil.move(img_move, destination_dir)
                        print(f"File '{img_move}' moved to '{destination_dir}' successfully.")
                    except Exception as e:
                        print(f"Error occurred while moving file: {e}")

# %%
train_valid_spilit(["ADI", "BACK", "DEB", "LYM", "MUC", "MUS", "NORM", "STR", "TUM"])

# %%
def fold_restructure(class_names):
    for class_name in tqdm(class_names, desc="Processing Classes"):
        for i in range(1,6):
            for start_idx in range(0, 1000):
                if start_idx < 800:
                    img_move = f"{base_path}/train/{class_name}_{i}_{start_idx}.jpg"
                    if not os.path.exists(img_move):
                        print(f"Source file '{img_move}' does not exist.")
                        return
                    
                    # Check if the destination directory exists, if not, create it
                    destination_dir = os.path.dirname(f"{base_path}/train/{class_name}/")
                    if not os.path.exists(destination_dir):
                        os.makedirs(destination_dir)
                    try:
                        shutil.move(img_move, destination_dir)
                        print(f"File '{img_move}' moved to '{destination_dir}' successfully.")
                    except Exception as e:
                        print(f"Error occurred while moving file: {e}")
                else:
                    img_move = f"{base_path}/val/{class_name}_{i}_{start_idx}.jpg"
                    if not os.path.exists(img_move):
                        print(f"Source file '{img_move}' does not exist.")
                        return
                    
                    # Check if the destination directory exists, if not, create it
                    destination_dir = os.path.dirname(f"{base_path}/val/{class_name}/")
                    if not os.path.exists(destination_dir):
                        os.makedirs(destination_dir)
                    try:
                        shutil.move(img_move, destination_dir)
                        print(f"File '{img_move}' moved to '{destination_dir}' successfully.")
                    except Exception as e:
                        print(f"Error occurred while moving file: {e}")

# %%
fold_restructure(["ADI", "BACK", "DEB", "LYM", "MUC", "MUS", "NORM", "STR", "TUM"])
# Out:
# Processing Classes:   0%|          | 0/9 [00:00<?, ?it/s]
# File './SSL_embeddings/Real/train/ADI_1_0.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_1.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_2.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_3.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_4.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_5.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_6.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_7.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_8.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_9.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_10.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_11.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_12.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_13.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_14.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_15.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_16.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_17.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_18.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_19.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_20.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_21.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_22.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_23.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_24.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_25.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_26.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_27.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_28.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_29.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_30.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_31.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_32.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_33.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_34.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_35.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_36.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_37.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_38.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_39.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_40.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_41.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_42.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_43.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_44.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_45.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_46.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_47.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_48.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_49.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_50.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_51.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_52.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_53.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_54.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_55.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_56.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_57.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_58.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_59.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_60.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_61.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_62.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_63.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_64.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_65.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_66.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_67.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_68.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_69.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_70.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_71.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_72.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_73.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_74.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_75.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_76.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_77.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_78.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_79.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_80.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_81.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_82.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_83.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_84.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_85.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_86.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_87.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_88.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_89.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_90.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_91.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_92.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_93.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_94.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_95.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_96.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_97.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_98.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_99.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_100.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_101.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_102.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_103.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_104.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_105.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_106.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_107.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_108.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_109.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_110.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_111.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_112.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_113.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_114.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_115.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_116.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_117.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_118.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_119.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_120.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_121.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_122.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_123.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_124.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_125.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_126.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_127.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_128.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_129.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_130.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_131.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_132.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_133.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_134.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_135.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_136.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_137.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_138.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_139.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_140.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_141.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_142.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_143.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_144.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_145.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_146.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_147.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_148.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_149.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_150.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_151.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_152.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_153.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_154.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_155.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_156.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_157.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_158.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_159.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_160.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_161.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_162.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_163.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_164.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_165.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_166.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_167.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_168.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_169.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_170.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_171.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_172.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_173.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_174.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_175.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_176.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_177.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_178.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_179.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_180.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_181.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_182.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_183.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_184.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_185.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_186.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_187.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_188.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_189.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_190.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_191.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_192.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_193.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_194.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_195.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_196.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_197.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_198.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_199.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_200.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_201.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_202.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_203.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_204.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_205.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_206.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_207.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_208.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_209.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_210.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_211.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_212.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_213.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_214.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_215.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_216.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_217.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_218.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_219.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_220.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_221.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_222.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_223.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_224.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_225.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_226.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_227.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_228.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_229.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_230.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_231.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_232.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_233.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_234.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_235.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_236.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_237.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_238.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_239.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_240.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_241.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_242.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_243.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_244.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_245.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_246.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_247.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_248.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_249.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_250.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_251.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_252.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_253.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_254.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_255.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_256.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_257.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1_258.jpg' moved to './SSL_embeddings/Real/train/ADI' successfully.
# File './SSL_embeddings/Real/train/ADI_1